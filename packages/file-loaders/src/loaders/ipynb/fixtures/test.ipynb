# %% [markdown]
# # Sample Notebook
#
# A tiny fixture covering common cell and output types.

# %%
print('hello')
# Out:
# hello

# %%
df.head(1)
# Out:
#    a
# 0  1

# %%
plot()

# %%
train()
# Out:
# 100%|##########
# done
